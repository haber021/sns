# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
sns.set_style(style="darkgrid")# "whitegrid")
# %matplotlib inline

# %%
df_group = pd.read_csv('https://raw.githubusercontent.com/Pitsillides91/Python-Tutorials/master/Seaborn%20Tutorial/Marketing%20Raw%20Data.csv?fbclid=IwAR2xpLwZkkvEhn4lo9bl5IT5fpgF-x7a7vRLuHB20AxIAUhxFmRTKlZ1t-A')
df_group.head()
# Out:
#          Date  Week  Week_ID  Month  Month_ID  Year   Day_Name  Visitors  \
# 0  09/11/2020    46       34     11        11  2020     Monday       707
# 1  10/11/2020    46       34     11        11  2020    Tuesday      1455
# 2  11/11/2020    46       34     11        11  2020  Wednesday      1520
# 3  12/11/2020    46       34     11        11  2020   Thursday      1726
# 4  13/11/2020    46       34     11        11  2020     Friday      2134
#
#    Revenue  Marketing Spend           Promo
# 0      465          651.375        No Promo
# 1    10386         1298.250   Promotion Red
# 2    12475         1559.375  Promotion Blue
# 3    11712         1801.750        No Promo
# 4    10000         2614.500        No Promo

# %%
ax = sns.lineplot(x='Week_ID', y='Revenue', data = df_group)

# %%
ax = sns.lineplot(x='Week_ID', y='Revenue', hue = 'Promo', data = df_group)

# %%
ax = sns.lineplot(x='Week_ID', y='Revenue', hue = 'Promo', style = 'Promo', data = df_group)

# %%
sns.set(rc={'figure.figsize':(12,10)})

ax = sns.lineplot(x='Week_ID', y='Revenue', hue = 'Promo', style = 'Promo', data = df_group, ci=None)

# %%
ax = sns.lineplot(x='Month_ID', y='Revenue', hue = 'Promo', style = 'Promo', data = df_group, ci=None,  markers=True)

# %%
ax = sns.lineplot(x='Month_ID', y='Revenue', hue = 'Day_Name', style = 'Promo', data = df_group, ci=None,  markers=True)

# %%
ax = sns.lineplot(x='Year', y='Revenue', hue = 'Day_Name', style = 'Promo', data = df_group, ci=None,  markers=True)

# %%
ax = sns.barplot(x="Month_ID", y="Revenue", data=df_group)
df_group[['Month_ID', 'Revenue']].groupby('Month_ID', as_index = False).agg({'Revenue':'mean'})
# Out:
#    Month_ID       Revenue
# 0        11  11255.454545
# 1        12  11667.806452
# 2        13   9588.516129
# 3        14  10683.892857
# 4        15  10555.354839
# 5        16  10806.500000
# 6        17   7636.000000

# %%
ax = sns.barplot(x="Month_ID", y="Revenue", data=df_group, ci=False)

# %%
ax = sns.barplot(x="Month_ID", y="Revenue", data=df_group, ci=False, hue = 'Promo')

# %%
ax = sns.barplot(x="Revenue", y="Year", ci=False, hue = 'Promo', orient = 'h', data=df_group)

# %%
# Example 5 - Total Revenue by Month - Remove the Confidence Interval - By Promo - Changing direction - Changing Colour
ax = sns.barplot(x="Revenue", y="Year", ci=False, hue = 'Promo', orient = 'h', data=df_group, color="#1CB3B1")

# Cool Way to pick colours
# https://htmlcolorcodes.com/color-picker/

# %%
x = df_group['Revenue'].values

sns.distplot(x, color = 'blue');
# Out:
# C:\Users\HABER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
x = df_group['Revenue'].values

sns.distplot(x, color = 'blue');

# Calculating the mean
mean = df_group['Revenue'].mean()

#ploting the mean
plt.axvline(mean, 0,1, color = 'red')
# Out:
# C:\Users\HABER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Example 3 - Investigating the distribution of Visitors, adding the mean

x = df_group['Visitors'].values

sns.distplot(x, color = 'red');

# Calculating the mean
mean = df_group['Visitors'].mean()

#ploting the mean
plt.axvline(mean, 0,1, color = 'blue')
# Out:
# C:\Users\HABER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
x = df_group['Revenue'].values

ax = sns.boxplot(x)

print('The meadian is: ', df_group['Revenue'].median())
# Out:
# C:\Users\HABER\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# The meadian is:  9452.0

# %%
PATH = "F:\\Github\\Python tutorials\\Introduction to Seaborn\\"
Image(filename = PATH + "Seaborn boxplot.png", width=900, height=900)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-e4db627eac9d> in <module>
#       1 PATH = "https://raw.githubusercontent.com/Pitsillides91/Python-Tutorials/master/Seaborn%20Tutorial/Marketing%20Raw%20Data.csv?fbclid=IwAR2xpLwZkkvEhn4lo9bl5IT5fpgF-x7a7vRLuHB20AxIAUhxFmRTKlZ1t-A"
# ----> 2 Image(filename = PATH + "https://raw.githubusercontent.com/Pitsillides91/Python-Tutorials/master/Seaborn%20Tutorial/Marketing%20Raw%20Data.csv?fbclid=IwAR2xpLwZkkvEhn4lo9bl5IT5fpgF-x7a7vRLuHB20AxIAUhxFmRTKlZ1t-A", width=900, height=900)
#
# NameError: name 'Image' is not defined

# %%
ax = sns.boxplot(x="Day_Name", y="Revenue", data=df_group)

# %%
ax = sns.boxplot(x="Revenue", y="Day_Name", data=df_group, color = '#EE67CF')

# %%
ax = sns.boxplot(x="Day_Name", y="Revenue", data=df_group, color="#B971E7", hue = 'Promo')

# %%
ax = sns.scatterplot(x="Marketing Spend", y="Revenue", data=df_group, color = 'green')

# %%
ax = sns.scatterplot(x="Marketing Spend", y="Revenue", data=df_group, color = 'green', hue = 'Promo', style = 'Promo')

# %%
# Example 3 - Relationship between Marketing Spend and Revenue - changing color & hue - adding size

ax = sns.scatterplot(x="Marketing Spend", y="Revenue", data=df_group, color = 'green', hue = 'Promo', size = 'Revenue',
                    sizes=(20, 200))

# %%
ax = sns.scatterplot(x="Visitors", y="Revenue", data=df_group, color = 'green', hue = 'Day_Name', size = 'Revenue',
                    sizes=(20, 200))

# %%
ax = sns.lmplot(x="Marketing Spend", y="Revenue", data=df_group, height=9)

# %%
ax = sns.lmplot(x="Marketing Spend", y="Revenue", data=df_group, height=9)

# %%
ax = sns.lmplot(x="Marketing Spend", y="Revenue", data=df_group, col = 'Promo', ci= False, height=5, 
                line_kws={'color': 'red'}, 
                scatter_kws={'color':'#ADC11E'})

# %%
ax = sns.lmplot(x="Visitors", y="Revenue", data=df_group, col = 'Day_Name', ci= False, height=4, 
                line_kws={'color': '#031722'}, 
                scatter_kws={'color':'#1E84C1'},
               col_wrap=3,
               x_jitter=.3)

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 7))
a = df_group['Revenue'].values
b = df_group['Visitors'].values
c = df_group['Marketing Spend'].values


# plot 1
sns.distplot(a, color = 'blue', ax=axes[0,0])

# plot 2
sns.distplot(b, color = 'blue', ax=axes[0,1])

# plot 3
sns.distplot(c, color = 'blue', ax=axes[1,0])

# plot 4
sns.boxplot(x="Revenue", y="Day_Name", data=df_group, color = '#52F954', ax=axes[1,1])
sns.swarmplot(x="Revenue", y="Day_Name", data=df_group, color="blue", ax=axes[1,1])
# Out:
# C:\Users\HABER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HABER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
g = sns.pairplot(df_group, plot_kws={'color':'green'})

# %%
g = sns.pairplot(df_group[['Revenue','Visitors','Marketing Spend']], plot_kws={'color':'#0EDCA9'})

# %%
g = sns.pairplot(df_group[['Revenue','Visitors','Marketing Spend', 'Promo']], hue = 'Promo')

# %%
g = sns.pairplot(df_group[['Revenue','Visitors','Marketing Spend', 'Promo']], hue = 'Promo', kind="reg", size = 6)
# Out:
# C:\Users\HABER\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
g = sns.jointplot("Revenue", "Marketing Spend", data=df_group, kind="reg", color = 'green', size = 10)
# Out:
# C:\Users\HABER\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HABER\anaconda3\lib\site-packages\seaborn\axisgrid.py:2182: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
pc = df_group[['Revenue','Visitors','Marketing Spend', 'Promo']].corr(method ='pearson')

cols = ['Revenue CC','Visitors CC','Marketing Spend CC']

ax = sns.heatmap(pc, annot=True,
                 yticklabels=cols,
                 xticklabels=cols,
                 annot_kws={'size': 50})
